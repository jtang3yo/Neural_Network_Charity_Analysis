# %% [markdown]
# To demonstrate how similar the logistic regression and basic neural network models are in terms of performance, we'll build and evaluate both models using the same training/testing dataset. First, we'll start by downloading this diabetes dataset (diabetes.csv) (Links to an external site.) and placing it in a folder with a new Jupyter Notebook. Next, we'll make a new Jupyter Notebook and name it "LogisticRegression_NeuralNet" (or something similar) to help us easily locate the comparison example at another time. Once we have created our notebook and placed the dataset into the corresponding folder, we'll start by importing our libraries and reading in the dataset. Copy and run the following code into the notebook:

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# Import our input dataset
diabetes_df = pd.read_csv('Resources/diabetes.csv')
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Remove diabetes outcome target from features data
y=diabetes_df.Outcome
X=diabetes_df.drop(columns = 'Outcome')

#split training/test datasets 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,
                                                   stratify=y)

# %%
#preprocess the numerical data for neural network 

# Create a StandardScaler instance
scaler = StandardScaler()
#fit the standardscaler 
X_scaler = scaler.fit(X_train)
#scale the data 
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# For our purposes, we'll use our basic logistic regression parameters, which include:
#
# The solver parameter is set to 'lbfgs', which is an algorithm for learning and optimization. The particular solver isn't very important in this example, but note that a number of optimizers exist.
# The max_iter parameter will be set to 200 iterations, which will give the model sufficient opportunity to converge on effective weights

# %%
#define the logistic regression instance 
log_classifier = LogisticRegression()

#train the model 
log_classifier.fit(X_train, y_train)
#evaluate the model 
y_pred=log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.729

# %% [markdown]
# Next, we need to build, compile, and evaluate our basic neural network model. Again, we'll use our typical binary classifier parameters:
#
# Our single hidden layer will have an input_dim equal to 8, 16 neuron units, and will use the relu activation function.
# The loss function should be binary_crossentropy, using the adam optimizer.
# Our model should provide the additional accuracy scoring metric and train over a maximum of 50 epochs.

# %%
#define basic neural network model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, input_dim=8,
                                  activation='relu'))
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer='adam',
                metrics=['accuracy'])
#train the model 
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)
#evaluate the model 
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f'Loss: {model_loss} and Accuracy: {model_accuracy}')
# Out:
# Epoch 1/50
# 18/18 [==============================] - 1s 1ms/step - loss: 0.7191 - accuracy: 0.4809
# Epoch 2/50
# 18/18 [==============================] - 0s 938us/step - loss: 0.6791 - accuracy: 0.5799
# Epoch 3/50
# 18/18 [==============================] - 0s 943us/step - loss: 0.6448 - accuracy: 0.6372
# Epoch 4/50
# 18/18 [==============================] - 0s 988us/step - loss: 0.6192 - accuracy: 0.6892
# Epoch 5/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5971 - accuracy: 0.7101
# Epoch 6/50
# 18/18 [==============================] - 0s 764us/step - loss: 0.5795 - accuracy: 0.7309
# Epoch 7/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5637 - accuracy: 0.7465
# Epoch 8/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5509 - accuracy: 0.7483
# Epoch 9/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5393 - accuracy: 0.7465
# Epoch 10/50
# 18/18 [==============================] - 0s 815us/step - loss: 0.5291 - accuracy: 0.7500
# Epoch 11/50
# 18/18 [==============================] - 0s 991us/step - loss: 0.5208 - accuracy: 0.7552
# Epoch 12/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5131 - accuracy: 0.7656
# Epoch 13/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5060 - accuracy: 0.7708
# Epoch 14/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.5000 - accuracy: 0.7691
# Epoch 15/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4947 - accuracy: 0.7726
# Epoch 16/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4900 - accuracy: 0.7726
# Epoch 17/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4854 - accuracy: 0.7743
# Epoch 18/50
# 18/18 [==============================] - 0s 916us/step - loss: 0.4816 - accuracy: 0.7760
# Epoch 19/50
# 18/18 [==============================] - 0s 929us/step - loss: 0.4779 - accuracy: 0.7778
# Epoch 20/50
# 18/18 [==============================] - 0s 899us/step - loss: 0.4750 - accuracy: 0.7830
# Epoch 21/50
# 18/18 [==============================] - 0s 827us/step - loss: 0.4722 - accuracy: 0.7830
# Epoch 22/50
# 18/18 [==============================] - 0s 844us/step - loss: 0.4703 - accuracy: 0.7830
# Epoch 23/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4674 - accuracy: 0.7812
# Epoch 24/50
# 18/18 [==============================] - 0s 981us/step - loss: 0.4652 - accuracy: 0.7812
# Epoch 25/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4635 - accuracy: 0.7795
# Epoch 26/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4617 - accuracy: 0.7795
# Epoch 27/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4601 - accuracy: 0.7812
# Epoch 28/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4586 - accuracy: 0.7812
# Epoch 29/50
# 18/18 [==============================] - 0s 952us/step - loss: 0.4574 - accuracy: 0.7830
# Epoch 30/50
# 18/18 [==============================] - 0s 937us/step - loss: 0.4560 - accuracy: 0.7847
# Epoch 31/50
# 18/18 [==============================] - 0s 837us/step - loss: 0.4550 - accuracy: 0.7830
# Epoch 32/50
# 18/18 [==============================] - 0s 862us/step - loss: 0.4540 - accuracy: 0.7812
# Epoch 33/50
# 18/18 [==============================] - 0s 828us/step - loss: 0.4530 - accuracy: 0.7812
# Epoch 34/50
# 18/18 [==============================] - 0s 828us/step - loss: 0.4518 - accuracy: 0.7847
# Epoch 35/50
# 18/18 [==============================] - 0s 902us/step - loss: 0.4509 - accuracy: 0.7847
# Epoch 36/50
# 18/18 [==============================] - 0s 720us/step - loss: 0.4500 - accuracy: 0.7847
# Epoch 37/50
# 18/18 [==============================] - 0s 827us/step - loss: 0.4496 - accuracy: 0.7830
# Epoch 38/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.7847
# Epoch 39/50
# 18/18 [==============================] - 0s 922us/step - loss: 0.4479 - accuracy: 0.7882
# Epoch 40/50
# 18/18 [==============================] - 0s 963us/step - loss: 0.4473 - accuracy: 0.7899
# Epoch 41/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.7882
# Epoch 42/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4457 - accuracy: 0.7917
# Epoch 43/50
# 18/18 [==============================] - 0s 901us/step - loss: 0.4453 - accuracy: 0.7899
# Epoch 44/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4446 - accuracy: 0.7882
# Epoch 45/50
# 18/18 [==============================] - 0s 990us/step - loss: 0.4440 - accuracy: 0.7899
# Epoch 46/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.7899
# Epoch 47/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.7882
# Epoch 48/50
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4427 - accuracy: 0.7865
# Epoch 49/50
# 18/18 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.7882
# Epoch 50/50
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4413 - accuracy: 0.7899
# 6/6 - 0s - loss: 0.4930 - accuracy: 0.7396
# Loss: 0.49297401309013367 and Accuracy: 0.7395833134651184

# %% [markdown]
# First, neural networks are prone to overfitting and can be more difficult to train than a straightforward logistic regression model. Therefore, if you are trying to build a classifier with limited data points (typically fewer than a thousand data points), or if your dataset has only a few features, neural networks may be overcomplicated. Additionally, logistic regression models are easier to dissect and interpret than their neural network counterparts, which tends to put more traditional data scientists and non-data experts at ease. In contrast, neural networks (and especially deep neural networks) thrive in large datasets. Datasets with thousands of data points, or datasets with complex features, may overwhelm the logistic regression model, while a deep learning model can evaluate every interaction within and across neurons. Therefore, the decision between using a logistic regression model and basic neural network model is nuanced and, in most cases, a matter of preference for the data scientist.
